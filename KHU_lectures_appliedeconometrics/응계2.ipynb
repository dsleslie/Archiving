# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.api as sm
from sklearn.model_selection import train_test_split
import warnings
warnings.filterwarnings("ignore")

from ggplot import *
from scipy.stats import logistic
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import *
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor, export_graphviz
import graphviz
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from sklearn.svm import SVC, SVR
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# %%
file1="c:/temp/final_english_int_zero.csv"
data1=pd.read_csv(file1)
data1
# Out:
#     district.e  year  school.zone  kindergarten  elementary  special  \
# 0       jongno  2019         49.0          16.0        13.0      3.0
# 1         jung  2019         41.0          11.0        12.0      0.0
# 2      yongsan  2019         39.0          15.0        15.0      0.0
# 3    seongdong  2019         52.0          21.0        21.0      0.0
# 4     gwangjin  2019         80.0          35.0        22.0      0.0
# ..         ...   ...          ...           ...         ...      ...
# 120     gwanak  2018         66.0          29.0        22.0      2.0
# 121     seocho  2018         59.0          17.0        24.0      1.0
# 122    gangnam  2018        104.0          24.0        33.0      2.0
# 123     songpa  2018         92.0          30.0        38.0      1.0
# 124   gangdong  2018         88.0          30.0        26.0      2.0
#
#      childcare.facility  population   vehicle  childaccident.schoolzone  ...  \
# ...

# %%
# OLS 1
y=data1['childaccident.schoolzone']
x=data1['school.zone']
X=sm.add_constant(x)
result1=sm.OLS(y,X).fit()
result1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                OLS Regression Results
# ...
# Dep. Variable:     childaccident.schoolzone   R-squared:                       0.395
# Model:                                  OLS   Adj. R-squared:                  0.390
# Method:                       Least Squares   F-statistic:                     80.15
# Date:                      Sun, 18 Jun 2023   Prob (F-statistic):           4.48e-15
# Time:                              21:30:28   Log-Likelihood:                -544.51
# No. Observations:                       125   AIC:                             1093.
# Df Residuals:                           123   BIC:                             1099.
# Df Model:                                 1
# Covariance Type:                  nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# ...

# %%
# OLS 2
y2=data1['childaccident.schoolzone']
x2=data1[['school.zone','vehicle','kindergarten','elementary','childcare.facility','population','trafficsafetyindex','violation.sum','trafficsafetyindex']]
X2=sm.add_constant(x2)
result2=sm.OLS(y2,X2).fit()
result2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                OLS Regression Results
# ...
# Dep. Variable:     childaccident.schoolzone   R-squared:                       0.760
# Model:                                  OLS   Adj. R-squared:                  0.743
# Method:                       Least Squares   F-statistic:                     45.81
# Date:                      Sun, 18 Jun 2023   Prob (F-statistic):           2.00e-32
# Time:                              21:30:28   Log-Likelihood:                -486.79
# No. Observations:                       125   AIC:                             991.6
# Df Residuals:                           116   BIC:                             1017.
# Df Model:                                 8
# Covariance Type:                  nonrobust
# ...
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# ...

# %%
data1
# Out:
#     district.e  year  school.zone  kindergarten  elementary  special  \
# 0       jongno  2019         49.0          16.0        13.0      3.0
# 1         jung  2019         41.0          11.0        12.0      0.0
# 2      yongsan  2019         39.0          15.0        15.0      0.0
# 3    seongdong  2019         52.0          21.0        21.0      0.0
# 4     gwangjin  2019         80.0          35.0        22.0      0.0
# ..         ...   ...          ...           ...         ...      ...
# 120     gwanak  2018         66.0          29.0        22.0      2.0
# 121     seocho  2018         59.0          17.0        24.0      1.0
# 122    gangnam  2018        104.0          24.0        33.0      2.0
# 123     songpa  2018         92.0          30.0        38.0      1.0
# 124   gangdong  2018         88.0          30.0        26.0      2.0
#
#      childcare.facility  population   vehicle  childaccident.schoolzone  ...  \
# ...

# %%
# OLS 3
y3=data1['childaccident.schoolzone']
x3=data1.drop(data1.columns[[0,1,2]],axis=1)
X3=sm.add_constant(x3)
result3=sm.OLS(y3,X3).fit()
result3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                OLS Regression Results
# ...
# Dep. Variable:     childaccident.schoolzone   R-squared:                       1.000
# Model:                                  OLS   Adj. R-squared:                  1.000
# Method:                       Least Squares   F-statistic:                 1.739e+25
# Date:                      Sun, 18 Jun 2023   Prob (F-statistic):               0.00
# Time:                              21:30:28   Log-Likelihood:                 2945.7
# No. Observations:                       125   AIC:                            -5853.
# Df Residuals:                           106   BIC:                            -5800.
# Df Model:                                18
# Covariance Type:                  nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# ...

# %%
data1
# Out:
#     district.e  year  school.zone  kindergarten  elementary  special  \
# 0       jongno  2019         49.0          16.0        13.0      3.0
# 1         jung  2019         41.0          11.0        12.0      0.0
# 2      yongsan  2019         39.0          15.0        15.0      0.0
# 3    seongdong  2019         52.0          21.0        21.0      0.0
# 4     gwangjin  2019         80.0          35.0        22.0      0.0
# ..         ...   ...          ...           ...         ...      ...
# 120     gwanak  2018         66.0          29.0        22.0      2.0
# 121     seocho  2018         59.0          17.0        24.0      1.0
# 122    gangnam  2018        104.0          24.0        33.0      2.0
# 123     songpa  2018         92.0          30.0        38.0      1.0
# 124   gangdong  2018         88.0          30.0        26.0      2.0
#
#      childcare.facility  population   vehicle  childaccident.schoolzone  ...  \
# ...

# %%
# OLS 4
y4=data1['childaccident.schoolzone']
x4=data1[['school.zone','population','vehicle']]
X4=sm.add_constant(x4)
result4=sm.OLS(y4,X4).fit()
result4.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                OLS Regression Results
# ...
# Dep. Variable:     childaccident.schoolzone   R-squared:                       0.643
# Model:                                  OLS   Adj. R-squared:                  0.634
# Method:                       Least Squares   F-statistic:                     72.51
# Date:                      Sun, 18 Jun 2023   Prob (F-statistic):           6.59e-27
# Time:                              21:30:28   Log-Likelihood:                -511.57
# No. Observations:                       125   AIC:                             1031.
# Df Residuals:                           121   BIC:                             1042.
# Df Model:                                 3
# Covariance Type:                  nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# ...

# %%
# OLS 5
y5=data1['childaccident.schoolzone']
x5=data1[['school.zone','No.safedriving','centerline','speeding','signal','Intersection','safety.distance']]
X5=sm.add_constant(x5)
result5=sm.OLS(y5,X5).fit()
result5.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                OLS Regression Results
# ...
# Dep. Variable:     childaccident.schoolzone   R-squared:                       0.731
# Model:                                  OLS   Adj. R-squared:                  0.715
# Method:                       Least Squares   F-statistic:                     45.36
# Date:                      Sun, 18 Jun 2023   Prob (F-statistic):           1.81e-30
# Time:                              21:30:28   Log-Likelihood:                -493.86
# No. Observations:                       125   AIC:                             1004.
# Df Residuals:                           117   BIC:                             1026.
# Df Model:                                 7
# Covariance Type:                  nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %%
# OLS 6
y6=np.log(data1['childaccident.schoolzone'])
x6=data1[['school.zone','No.safedriving','centerline','speeding','signal','Intersection','safety.distance']]
X6=sm.add_constant(x6)
result6=sm.OLS(y6,X6).fit()
result6.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                OLS Regression Results
# ...
# Dep. Variable:     childaccident.schoolzone   R-squared:                       0.604
# Model:                                  OLS   Adj. R-squared:                  0.581
# Method:                       Least Squares   F-statistic:                     25.54
# Date:                      Sun, 18 Jun 2023   Prob (F-statistic):           6.74e-21
# Time:                              21:30:28   Log-Likelihood:                -30.230
# No. Observations:                       125   AIC:                             76.46
# Df Residuals:                           117   BIC:                             99.09
# Df Model:                                 7
# Covariance Type:                  nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %%
# OLS 7
y7=np.log(data1['childaccident.schoolzone'])
x7=data1['school.zone']
X7=sm.add_constant(x7)
result7=sm.OLS(y7,X7).fit()
result7.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                OLS Regression Results
# ...
# Dep. Variable:     childaccident.schoolzone   R-squared:                       0.382
# Model:                                  OLS   Adj. R-squared:                  0.377
# Method:                       Least Squares   F-statistic:                     76.10
# Date:                      Sun, 18 Jun 2023   Prob (F-statistic):           1.57e-14
# Time:                              21:30:28   Log-Likelihood:                -58.098
# No. Observations:                       125   AIC:                             120.2
# Df Residuals:                           123   BIC:                             125.9
# Df Model:                                 1
# Covariance Type:                  nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# ...

# %%
# OLS 1
y=data1['childaccident.schoolzone']
x=data1['school.zone']
X=sm.add_constant(x)
result1=sm.OLS(y,X).fit()
result1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                OLS Regression Results
# ...
# Dep. Variable:     childaccident.schoolzone   R-squared:                       0.395
# Model:                                  OLS   Adj. R-squared:                  0.390
# Method:                       Least Squares   F-statistic:                     80.15
# Date:                      Sun, 18 Jun 2023   Prob (F-statistic):           4.48e-15
# Time:                              21:30:28   Log-Likelihood:                -544.51
# No. Observations:                       125   AIC:                             1093.
# Df Residuals:                           123   BIC:                             1099.
# Df Model:                                 1
# Covariance Type:                  nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# ...

# %%
# OLS 5
y5=data1['childaccident.schoolzone']
x5=data1[['school.zone','No.safedriving','centerline','speeding','signal','Intersection','safety.distance']]
X5=sm.add_constant(x5)
result5=sm.OLS(y5,X5).fit()
result5.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                OLS Regression Results
# ...
# Dep. Variable:     childaccident.schoolzone   R-squared:                       0.731
# Model:                                  OLS   Adj. R-squared:                  0.715
# Method:                       Least Squares   F-statistic:                     45.36
# Date:                      Sun, 18 Jun 2023   Prob (F-statistic):           1.81e-30
# Time:                              21:30:28   Log-Likelihood:                -493.86
# No. Observations:                       125   AIC:                             1004.
# Df Residuals:                           117   BIC:                             1026.
# Df Model:                                 7
# Covariance Type:                  nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %%
# 2SLS 1
y_2=data1['childaccident.schoolzone']
X_2=data1[['school.zone','No.safedriving','centerline','speeding','signal','Intersection','safety.distance']]

dependent=data1['childaccident.schoolzone']
exog=sm.add_constant
endog=data1['school.zone']
instruments=data1['population']

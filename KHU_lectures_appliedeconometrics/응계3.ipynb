# %%
pip install statsmodels
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install linearmodels
# Out:
# ...
#
# ...

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.api as sm
from sklearn.model_selection import train_test_split
import warnings
warnings.filterwarnings("ignore")


from ggplot import *
from scipy.stats import logistic
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import *
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor, export_graphviz
import graphviz
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from sklearn.svm import SVC, SVR
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler


from linearmodels.iv import IV2SLS
from linearmodels.datasets import mroz

# %%
file1="c:/temp/final_english_int_zero.csv"
data1=pd.read_csv(file1)
data1
# Out:
#     district.e  year  school.zone  kindergarten  elementary  special  \
# 0       jongno  2019         49.0          16.0        13.0      3.0
# 1         jung  2019         41.0          11.0        12.0      0.0
# 2      yongsan  2019         39.0          15.0        15.0      0.0
# 3    seongdong  2019         52.0          21.0        21.0      0.0
# 4     gwangjin  2019         80.0          35.0        22.0      0.0
# ..         ...   ...          ...           ...         ...      ...
# 120     gwanak  2018         66.0          29.0        22.0      2.0
# 121     seocho  2018         59.0          17.0        24.0      1.0
# 122    gangnam  2018        104.0          24.0        33.0      2.0
# 123     songpa  2018         92.0          30.0        38.0      1.0
# 124   gangdong  2018         88.0          30.0        26.0      2.0
#
#      childcare.facility  population   vehicle  childaccident.schoolzone  ...  \
# ...

# %%
# OLS 1
y=data1['childaccident.schoolzone']
x=data1['school.zone']
X=sm.add_constant(x)
result1=sm.OLS(y,X).fit()
result1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                OLS Regression Results
# ...
# Dep. Variable:     childaccident.schoolzone   R-squared:                       0.395
# Model:                                  OLS   Adj. R-squared:                  0.390
# Method:                       Least Squares   F-statistic:                     80.15
# Date:                      Sun, 18 Jun 2023   Prob (F-statistic):           4.48e-15
# Time:                              21:44:07   Log-Likelihood:                -544.51
# No. Observations:                       125   AIC:                             1093.
# Df Residuals:                           123   BIC:                             1099.
# Df Model:                                 1
# Covariance Type:                  nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# ...

# %%
# OLS 2
y2=data1['childaccident.schoolzone']
x2=data1[['school.zone','No.safedriving','centerline','speeding','signal','Intersection','safety.distance']]
X2=sm.add_constant(x2)
result2=sm.OLS(y2,X2).fit()
result2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                OLS Regression Results
# ...
# Dep. Variable:     childaccident.schoolzone   R-squared:                       0.731
# Model:                                  OLS   Adj. R-squared:                  0.715
# Method:                       Least Squares   F-statistic:                     45.36
# Date:                      Sun, 18 Jun 2023   Prob (F-statistic):           1.81e-30
# Time:                              21:44:07   Log-Likelihood:                -493.86
# No. Observations:                       125   AIC:                             1004.
# Df Residuals:                           117   BIC:                             1026.
# Df Model:                                 7
# Covariance Type:                  nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %%
import statsmodels.api as sm
from linearmodels.iv import IV2SLS

dependent = data1['childaccident.schoolzone']
exog = sm.add_constant(data1['school.zone'])
endog = data1['vehicle']
instruments = data1['population']

model = IV2SLS(dependent, exog, endog, instruments)
result1 = model.fit()
result1.summary
# Out:
# <class 'linearmodels.compat.statsmodels.Summary'>
# """
#                              IV-2SLS Estimation Summary
# ...
# Dep. Variable:     childaccident.schoolzone   R-squared:                      0.5919
# Estimator:                          IV-2SLS   Adj. R-squared:                 0.5852
# No. Observations:                       125   F-statistic:                    162.42
# Date:                      Sun, Jun 18 2023   P-value (F-stat)                0.0000
# Time:                              21:56:39   Distribution:                  chi2(2)
# Cov. Estimator:                      robust
#
#                               Parameter Estimates
# ...
#              Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -------------------------------------------------------------------------------
# const           6.5066     12.255     0.5309     0.5955     -17.513      30.526
# vehicle         0.0004     0.0002     2.8518     0.0043      0.0001      0.0007
# ...

# %%
file2="c:/temp/final_edit.csv"
data2=pd.read_csv(file2)
data2
# Out:
#    district.e  year  school.zone  population   vehicle  \
# 0      jongno  2019         49.0     73947.0   50052.0
# 1        jung  2019         41.0     62739.0   51736.0
# 2     yongsan  2019         39.0    110126.0   76521.0
# 3   seongdong  2019         52.0    135838.0  106263.0
# 4    gwangjin  2019         80.0    164428.0   99299.0
# ..        ...   ...          ...         ...       ...
# 69     gwanak  2018         66.0    262222.0  121430.0
# 70     seocho  2018         59.0    172918.0  182123.0
# 71    gangnam  2018        104.0    228775.0  235314.0
# 72     songpa  2018         92.0    270866.0  236179.0
# 73   gangdong  2018         88.0    177247.0  135420.0
#
#     childaccident.schoolzone  trafficsafetyindex  elderlyaccident  \
# 0                       20.0               79.77            184.0
# 1                       24.0               75.09            151.0
# 2                       27.0               79.64            144.0
# ...

# %%
# OLS 3
y3=data2['childaccident.schoolzone']
x3=data2['school.zone']
X3=sm.add_constant(x3)
result3=sm.OLS(y3,X3).fit()
result3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                OLS Regression Results
# ...
# Dep. Variable:     childaccident.schoolzone   R-squared:                       0.400
# Model:                                  OLS   Adj. R-squared:                  0.392
# Method:                       Least Squares   F-statistic:                     48.05
# Date:                      Sun, 18 Jun 2023   Prob (F-statistic):           1.48e-09
# Time:                              22:58:02   Log-Likelihood:                -323.29
# No. Observations:                        74   AIC:                             650.6
# Df Residuals:                            72   BIC:                             655.2
# Df Model:                                 1
# Covariance Type:                  nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# ...

# %%
# OLS 4
y4=data2['childaccident.schoolzone']
x4=data2[['school.zone','No.safedriving','centerline','speeding','signal','Intersection','safety.distance']]
X4=sm.add_constant(x4)
result4=sm.OLS(y4,X4).fit()
result4.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                OLS Regression Results
# ...
# Dep. Variable:     childaccident.schoolzone   R-squared:                       0.716
# Model:                                  OLS   Adj. R-squared:                  0.686
# Method:                       Least Squares   F-statistic:                     23.81
# Date:                      Sun, 18 Jun 2023   Prob (F-statistic):           8.36e-16
# Time:                              23:00:56   Log-Likelihood:                -295.59
# No. Observations:                        74   AIC:                             607.2
# Df Residuals:                            66   BIC:                             625.6
# Df Model:                                 7
# Covariance Type:                  nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %%
# OLS 5
y5=data2['childaccident.schoolzone']
x5=data2[['school.zone','population','vehicle']]
X5=sm.add_constant(x5)
result5=sm.OLS(y5,X5).fit()
result5.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                OLS Regression Results
# ...
# Dep. Variable:     childaccident.schoolzone   R-squared:                       0.670
# Model:                                  OLS   Adj. R-squared:                  0.656
# Method:                       Least Squares   F-statistic:                     47.35
# Date:                      Sun, 18 Jun 2023   Prob (F-statistic):           7.89e-17
# Time:                              23:08:42   Log-Likelihood:                -301.20
# No. Observations:                        74   AIC:                             610.4
# Df Residuals:                            70   BIC:                             619.6
# Df Model:                                 3
# Covariance Type:                  nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# ...

# %%
# OLS 5
y5=data2['childaccident.schoolzone']
x5=data2[['school.zone','vehicle','violation.sum']]
X5=sm.add_constant(x5)
result5=sm.OLS(y5,X5).fit()
result5.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                OLS Regression Results
# ...
# Dep. Variable:     childaccident.schoolzone   R-squared:                       0.679
# Model:                                  OLS   Adj. R-squared:                  0.665
# Method:                       Least Squares   F-statistic:                     49.39
# Date:                      Sun, 18 Jun 2023   Prob (F-statistic):           2.94e-17
# Time:                              23:09:25   Log-Likelihood:                -300.15
# No. Observations:                        74   AIC:                             608.3
# Df Residuals:                            70   BIC:                             617.5
# Df Model:                                 3
# Covariance Type:                  nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %%
data2
# Out:
#    district.e  year  school.zone  population   vehicle  \
# 0      jongno  2019         49.0     73947.0   50052.0
# 1        jung  2019         41.0     62739.0   51736.0
# 2     yongsan  2019         39.0    110126.0   76521.0
# 3   seongdong  2019         52.0    135838.0  106263.0
# 4    gwangjin  2019         80.0    164428.0   99299.0
# ..        ...   ...          ...         ...       ...
# 69     gwanak  2018         66.0    262222.0  121430.0
# 70     seocho  2018         59.0    172918.0  182123.0
# 71    gangnam  2018        104.0    228775.0  235314.0
# 72     songpa  2018         92.0    270866.0  236179.0
# 73   gangdong  2018         88.0    177247.0  135420.0
#
#     childaccident.schoolzone  trafficsafetyindex  elderlyaccident  \
# 0                       20.0               79.77            184.0
# 1                       24.0               75.09            151.0
# 2                       27.0               79.64            144.0
# ...

# %%
# OLS n
y=data2['childaccident.schoolzone']
x=data2.drop(data2.columns[[0,1]],axis=1)
X=sm.add_constant(x)
result=sm.OLS(y,X).fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                OLS Regression Results
# ...
# Dep. Variable:     childaccident.schoolzone   R-squared:                       1.000
# Model:                                  OLS   Adj. R-squared:                  1.000
# Method:                       Least Squares   F-statistic:                 4.621e+26
# Date:                      Sun, 18 Jun 2023   Prob (F-statistic):               0.00
# Time:                              23:13:28   Log-Likelihood:                 1876.3
# No. Observations:                        74   AIC:                            -3723.
# Df Residuals:                            59   BIC:                            -3688.
# Df Model:                                14
# Covariance Type:                  nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# ...

# %%
data2
# Out:
#    district.e  year  school.zone  population   vehicle  \
# 0      jongno  2019         49.0     73947.0   50052.0
# 1        jung  2019         41.0     62739.0   51736.0
# 2     yongsan  2019         39.0    110126.0   76521.0
# 3   seongdong  2019         52.0    135838.0  106263.0
# 4    gwangjin  2019         80.0    164428.0   99299.0
# ..        ...   ...          ...         ...       ...
# 69     gwanak  2018         66.0    262222.0  121430.0
# 70     seocho  2018         59.0    172918.0  182123.0
# 71    gangnam  2018        104.0    228775.0  235314.0
# 72     songpa  2018         92.0    270866.0  236179.0
# 73   gangdong  2018         88.0    177247.0  135420.0
#
#     childaccident.schoolzone  trafficsafetyindex  elderlyaccident  \
# 0                       20.0               79.77            184.0
# 1                       24.0               75.09            151.0
# 2                       27.0               79.64            144.0
# ...

# %%
# OLS n
y=data2['childaccident.schoolzone']
x=data2[['school.zone','population','vehicle','trafficsafetyindex','elderlyaccident','violation.sum','No.safedriving','centerline','speeding','signal','Intersection','safety.distance','hitandrun']]
X=sm.add_constant(x)
result=sm.OLS(y,X).fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                OLS Regression Results
# ...
# Dep. Variable:     childaccident.schoolzone   R-squared:                       0.785
# Model:                                  OLS   Adj. R-squared:                  0.739
# Method:                       Least Squares   F-statistic:                     16.88
# Date:                      Sun, 18 Jun 2023   Prob (F-statistic):           2.02e-15
# Time:                              23:34:04   Log-Likelihood:                -285.28
# No. Observations:                        74   AIC:                             598.6
# Df Residuals:                            60   BIC:                             630.8
# Df Model:                                13
# Covariance Type:                  nonrobust
# ...
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# ...

# %%
# OLS n
y=data2['childaccident.schoolzone']
x=data2[['school.zone','trafficsafetyindex','elderlyaccident','No.safedriving','centerline','speeding','signal','Intersection','safety.distance','hitandrun']]
X=sm.add_constant(x)
result=sm.OLS(y,X).fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                OLS Regression Results
# ...
# Dep. Variable:     childaccident.schoolzone   R-squared:                       0.740
# Model:                                  OLS   Adj. R-squared:                  0.698
# Method:                       Least Squares   F-statistic:                     17.90
# Date:                      Sun, 18 Jun 2023   Prob (F-statistic):           6.74e-15
# Time:                              23:35:02   Log-Likelihood:                -292.41
# No. Observations:                        74   AIC:                             606.8
# Df Residuals:                            63   BIC:                             632.2
# Df Model:                                10
# Covariance Type:                  nonrobust
# ...
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# ...

# %%
# OLS n
y=data2['childaccident.schoolzone']
x=data2[['school.zone','No.safedriving','centerline','speeding','signal','Intersection','safety.distance','hitandrun']]
X=sm.add_constant(x)
result=sm.OLS(y,X).fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                OLS Regression Results
# ...
# Dep. Variable:     childaccident.schoolzone   R-squared:                       0.728
# Model:                                  OLS   Adj. R-squared:                  0.694
# Method:                       Least Squares   F-statistic:                     21.71
# Date:                      Sun, 18 Jun 2023   Prob (F-statistic):           1.20e-15
# Time:                              23:35:39   Log-Likelihood:                -294.09
# No. Observations:                        74   AIC:                             606.2
# Df Residuals:                            65   BIC:                             626.9
# Df Model:                                 8
# Covariance Type:                  nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %%
# OLS n
y=data2['childaccident.schoolzone']
x=data2[['school.zone','No.safedriving','centerline','speeding','signal','safety.distance','hitandrun']]
X=sm.add_constant(x)
result=sm.OLS(y,X).fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                OLS Regression Results
# ...
# Dep. Variable:     childaccident.schoolzone   R-squared:                       0.720
# Model:                                  OLS   Adj. R-squared:                  0.691
# Method:                       Least Squares   F-statistic:                     24.27
# Date:                      Sun, 18 Jun 2023   Prob (F-statistic):           5.39e-16
# Time:                              23:39:15   Log-Likelihood:                -295.08
# No. Observations:                        74   AIC:                             606.2
# Df Residuals:                            66   BIC:                             624.6
# Df Model:                                 7
# Covariance Type:                  nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %%
# OLS n
y=data2['school.zone']
x=data2['childaccident.schoolzone']
X=sm.add_constant(x)
result=sm.OLS(y,X).fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:            school.zone   R-squared:                       0.400
# Model:                            OLS   Adj. R-squared:                  0.392
# Method:                 Least Squares   F-statistic:                     48.05
# Date:                Sun, 18 Jun 2023   Prob (F-statistic):           1.48e-09
# Time:                        23:40:33   Log-Likelihood:                -316.69
# No. Observations:                  74   AIC:                             637.4
# Df Residuals:                      72   BIC:                             642.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# ...

# %%
# OLS 1
y=data2['childaccident.schoolzone']
x=data2['school.zone']
X=sm.add_constant(x)
result=sm.OLS(y,X).fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                OLS Regression Results
# ...
# Dep. Variable:     childaccident.schoolzone   R-squared:                       0.400
# Model:                                  OLS   Adj. R-squared:                  0.392
# Method:                       Least Squares   F-statistic:                     48.05
# Date:                      Mon, 19 Jun 2023   Prob (F-statistic):           1.48e-09
# Time:                              00:13:46   Log-Likelihood:                -323.29
# No. Observations:                        74   AIC:                             650.6
# Df Residuals:                            72   BIC:                             655.2
# Df Model:                                 1
# Covariance Type:                  nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# ...

# %%
# OLS 2
y=data2['childaccident.schoolzone']
x=data2[['school.zone','No.safedriving','centerline','speeding','signal','safety.distance','hitandrun']]
X=sm.add_constant(x)
result=sm.OLS(y,X).fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                OLS Regression Results
# ...
# Dep. Variable:     childaccident.schoolzone   R-squared:                       0.720
# Model:                                  OLS   Adj. R-squared:                  0.691
# Method:                       Least Squares   F-statistic:                     24.27
# Date:                      Mon, 19 Jun 2023   Prob (F-statistic):           5.39e-16
# Time:                              00:14:04   Log-Likelihood:                -295.08
# No. Observations:                        74   AIC:                             606.2
# Df Residuals:                            66   BIC:                             624.6
# Df Model:                                 7
# Covariance Type:                  nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %%
# OLS 3
y=data2['childaccident.schoolzone']
x=data2[['school.zone','No.safedriving','centerline','speeding','signal','safety.distance']]
X=sm.add_constant(x)
result=sm.OLS(y,X).fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                OLS Regression Results
# ...
# Dep. Variable:     childaccident.schoolzone   R-squared:                       0.707
# Model:                                  OLS   Adj. R-squared:                  0.680
# Method:                       Least Squares   F-statistic:                     26.91
# Date:                      Mon, 19 Jun 2023   Prob (F-statistic):           4.46e-16
# Time:                              00:14:47   Log-Likelihood:                -296.82
# No. Observations:                        74   AIC:                             607.6
# Df Residuals:                            67   BIC:                             623.8
# Df Model:                                 6
# Covariance Type:                  nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %%
data2
# Out:
#    district.e  year  school.zone  population   vehicle  \
# 0      jongno  2019         49.0     73947.0   50052.0
# 1        jung  2019         41.0     62739.0   51736.0
# 2     yongsan  2019         39.0    110126.0   76521.0
# 3   seongdong  2019         52.0    135838.0  106263.0
# 4    gwangjin  2019         80.0    164428.0   99299.0
# ..        ...   ...          ...         ...       ...
# 69     gwanak  2018         66.0    262222.0  121430.0
# 70     seocho  2018         59.0    172918.0  182123.0
# 71    gangnam  2018        104.0    228775.0  235314.0
# 72     songpa  2018         92.0    270866.0  236179.0
# 73   gangdong  2018         88.0    177247.0  135420.0
#
#     childaccident.schoolzone  trafficsafetyindex  elderlyaccident  \
# 0                       20.0               79.77            184.0
# 1                       24.0               75.09            151.0
# 2                       27.0               79.64            144.0
# ...

# %%
import statsmodels.api as sm
from linearmodels.iv import IV2SLS

dependent = data2['childaccident.schoolzone']
exog = data2[['vehicle','trafficsafetyindex','No.safedriving','centerline','speeding','signal','safety.distance']]
endog = data2['school.zone']
instruments = data2['population']

model = IV2SLS(dependent, exog, endog, instruments)
result1 = model.fit()
result1.summary
# Out:
# <class 'linearmodels.compat.statsmodels.Summary'>
# """
#                              IV-2SLS Estimation Summary
# ...
# Dep. Variable:     childaccident.schoolzone   R-squared:                      0.9618
# Estimator:                          IV-2SLS   Adj. R-squared:                 0.9572
# No. Observations:                        74   F-statistic:                    2176.4
# Date:                      Mon, Jun 19 2023   P-value (F-stat)                0.0000
# Time:                              00:48:32   Distribution:                  chi2(8)
# Cov. Estimator:                      robust
#
#                                  Parameter Estimates
# ...
#                     Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# --------------------------------------------------------------------------------------
# vehicle                0.0003     0.0002     1.1125     0.2659     -0.0002      0.0007
# ...

# %%
import statsmodels.api as sm
from linearmodels.iv import IV2SLS

dependent = data2['childaccident.schoolzone']
exog = data2[['vehicle','trafficsafetyindex','violation.sum']]
endog = data2['school.zone']
instruments = data2['population']

model = IV2SLS(dependent, exog, endog, instruments)
result1 = model.fit()
result1.summary
# Out:
# <class 'linearmodels.compat.statsmodels.Summary'>
# """
#                              IV-2SLS Estimation Summary
# ...
# Dep. Variable:     childaccident.schoolzone   R-squared:                      0.9293
# Estimator:                          IV-2SLS   Adj. R-squared:                 0.9253
# No. Observations:                        74   F-statistic:                    999.37
# Date:                      Mon, Jun 19 2023   P-value (F-stat)                0.0000
# Time:                              00:49:15   Distribution:                  chi2(4)
# Cov. Estimator:                      robust
#
#                                  Parameter Estimates
# ...
#                     Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# --------------------------------------------------------------------------------------
# vehicle             5.798e-05     0.0003     0.2114     0.8326     -0.0005      0.0006
# ...

# %%
import statsmodels.api as sm
from linearmodels.iv import IV2SLS

dependent = data2['childaccident.schoolzone']
exog = data2[['vehicle','trafficsafetyindex','violation.sum']]
endog = data2['school.zone']
instruments = data2['population']

model = IV2SLS(dependent, exog, endog, instruments)
result1 = model.fit()
result1.summary
